# %% [markdown]
# Starting point: https://en.wikipedia.org/wiki/List_of_countries_by_the_number_of_billionaires

# %%
import pandas as pd
import requests

# %%
# Retrieve the tables on the page
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_the_number_of_billionaires'
content = requests.get(url).text
table = pd.read_html( content, header=0 )[3]

# %%
table
# Out:
#     Worldrank Country or dependency Number ofbillionaires  \
# 0           1         United States                   585
# 1           2                 China                   476
# 2           3              India[3]                   131
# 3           4               Germany                   114
# 4           5                Russia                    96
# 5           6             Hong Kong                    67
# 6           7        United Kingdom                    54
# 7           8                Brazil                    43
# 8           9                 Italy                    42
# 9          10                Canada                    39
# 10         11                France                    38
# 11         11           South Korea                    38
# 12         13           Switzerland                    36
# 13         14             Australia                    33
# 14         14                 Japan                    33
# ...
